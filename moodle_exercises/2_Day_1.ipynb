# %%
teacher_name = "Dan"
print(teacher_name)
teacher_name = "Daniubus"
print(teacher_name)

print("My teacher this evening is: " + teacher_name)
# Out:
# Dan
# Daniubus
# My teacher this evening is: Daniubus

# %%
# what if there's two equals signs
instructor_name = "Daniubus"
print(instructor_name)
# example of something that is equal
print(instructor_name == teacher_name)
# example of something that is not equal
print(instructor_name == "Marshmallow")
# Out:
# Daniubus
# True
# False

# %%
# Let's take a look at some numbers

students = 40
teachers = 1
pens = 2.9

print(students)
# let's update students because steve the ghost came into classroom

students = 40 + 1
print(students)
# Out:
# 40
# 41

# %%
print("There are "+ str(students) + " students in the class")
# Out:
# There are 41 students in the class

# %%
print(type(students))
print(students)
# Out:
# <class 'int'>
# 41

# %%
# input as an example

number_of_cats = input("please enter the number of cats you have:")
print("you have "+ number_of_cats + " cats")
print(type(number_of_cats))

cans_of_cat_food_per_day = int(number_of_cats) * 2
print(cans_of_cat_food_per_day)
print(type(cans_of_cat_food_per_day))
print("you need to get at least " + str(cans_of_cat_food_per_day) + " cans of food per day for your cats")
# Out:
# please enter the number of cats you have:daniel mouri9s
# you have daniel mouri9s cats
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9b0d28ee2273> in <module>()
#       5 print(type(number_of_cats))
#       6
# ----> 7 cans_of_cat_food_per_day = int(number_of_cats) * 2
#       8 print(cans_of_cat_food_per_day)
#       9 print(type(cans_of_cat_food_per_day))
#
# ValueError: invalid literal for int() with base 10: 'daniel mouri9s'

# %%
# example of nameerror
print("hi " + cat_name)
cat_name = "Gambit"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-87a1688e3a19> in <module>()
# ----> 1 print("hi " + cat_name)
#       2 cat_name = "Gambit"
#
# NameError: name 'cat_name' is not defined

# %%
# successful example 
cat_name = "Gambit"
print("hi " + cat_name)
# Out:
# hi Gambit

# %%
number_of_students  = 39
# example of multiplication
print(number_of_students * 3.0)

# example of division
print(number_of_students / 3)

# example of floor 
print(number_of_students // 3)

# how do i find the remainder
print(number_of_students % 3)

# rounding
third_of_students = number_of_students / 3
print(round(third_of_students, 2))

# adding
print(number_of_students + 2)

# subtracting

print(number_of_students - 10)
# Out:
# 117.0
# 13.0
# 13
# 0
# 13.0
# 41
# 29

# %%
number_of_cats = 3

# powers example
print((number_of_cats**2)/2)
# Out:
# 4.5

# %%
# example of import the entire module.
import math

print(math.sqrt(9))
# Out:
# 3.0

# %%
# example of importing part of the module
from math import sqrt

print(sqrt(4))
# Out:
# 2.0

# %%
# more modulo questions
testing_modulo = 9
print(testing_modulo/4)
print(testing_modulo//4)
print(testing_modulo%4)
# Out:
# 2.25
# 2
# 1
